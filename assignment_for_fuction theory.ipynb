# %% [markdown]
# **Question1**: What is differnce between a function and a method in the python.
# **Answer:**  function is  block of code designed to perform a specific task, defined using the def keyword and can be called anywhere in the program while a method is the  function that is associated with an object, defined inside a class, and can operate on data contained within the object.

# %%
def fun(x):
  if x%2==0:
    return 'even'
  else:
    return "odd"
print(fun(5))   # this is function


#method
class Person:
    def __init__(self, name):
        self.name = name

    def greet(self):
        return f"Hello, {self.name}!"

person = Person("Bob")
print(person.greet())
# Out:
# odd
# Hello, Bob!

# %% [markdown]
# **Question 2**:Explain the concept of function arguments and the parameters in python.
# **Answer**: The parameter are the variable which we gives when we define the function and the arguments are the values which we actually pass when we call the function.
# the example is given below.

# %%
#exqmple for question 2
def func(parameter): # here in the paranthesis is parameter
    return f" the name of the parameter is {parameter}"

func("argument") #here is the argument
# Out:
# ' the name of the parameter is argument'

# %% [markdown]
# **Question 3:** What is the differnt way to define and call the function in python?
# **Answer**:There are multiple ways to define the function
#  firstly the conventionation method of using def and then write the block of the function
# other one are lambda and map
# example is given in the code bellow

# %%
#example for question number 3
def check_even(x):
  if x%2==0:
    return 'even number'
  else:
    return "odd number"
check_even(10)
# Out:
# 'even number'

# %%
x=55
result= lambda x: "even number" if x%2==0 else "odd number",l
print(result)
# Out:
# (<function <lambda> at 0x7da9672d8d30>, [10])

# %% [markdown]
# **Question4**: what is the purpose of the return statment in  the python function?
# **Answer**:The main purpose of the return statment is to provide the result to user and end the function execution and it also important when the function is used recursivly because the result of the previous itartion are used multiple times

# %%
# example for question 4
def greet(name):
  return f" hello mr. {name}"
greet("mithlesh") #here the result is given through the return statment
# Out:
# ' hello mr. mithlesh'

# %% [markdown]
# Question5: what are itrators in the python and how the are differnt from itrables?
# Answer: An iterator is an object in Python that enables traversal through all elements of a collection like a list or a tuple one by one
# whreas the itrables are the object on which the itrator works on they are basically the collecton of the data which can be retrive on by one .

# %%
mytuple = ("apple", "banana", "cherry") #here tuple is itrable object whre the iter function works
myit = iter(mytuple)                    # which means iter is the itrator
print(next(myit))
print(next(myit))
# Out:
# apple
# banana

# %% [markdown]
# **question 6** Explain the concept of generator in python  and how they are defined.
# **Answer**: Generator functions in Python are a way to create iterators in a more concise and memory-efficient manner
#  These functions allow you to iterate over a potentially large sequence of data without loading the entire
# sequence into memory. They are defined just by putting
# yeild instead of return in the definition of the function

# %%
def countdown(n):
  while n > 0:
    yield n
    n -= 1
# Using the generator for a countdown
countdown_gen = countdown(5)
for number in countdown_gen:
  print(number,end=" ")
# Out:
# 5 4 3 2 1

# %% [markdown]
# **Question7**:What are the advantages of using generators over regular functions?
# **Answer:**The most noticiable advantage of the generator funtion is the when data set is very big then this function can use memory very efficiently because it do not store entire data set in the memory so for big data set we can have the result without the machine goes  out of memory.
# it is faster then the reguar function as it have not to do unnecessery computation.

# %% [markdown]
# **Question8**: What is a lambda function in Python and when is it typically used?
# **Answer**:A lambda function in Python is a concise way to create anonymous functions, also known as lambda
# expressions  Unlike regular functions defined using the def keyword, lambda functions are often used for short-term
# operations and are defined in a single line.
# Ideal for small functions that are simple enough to be expressed in a single line

# %%
square=lambda x:x**2 #example 1
print(square(2))
even= lambda x: True if x%2==0 else False #example 2
print(even(4567))
# Out:
# 4
# False

# %% [markdown]
# **Question 9**. Explain the purpose and usage of the `map()` function in Python.
# **Answer**:The `map()` function executes a specified function for each item in an `iterable`. The item is sent to the
# function as a parameter
#  The map() function in Python is a built-in function that applies a given function to all the items in an iterable
# (e.g., a list) and returns an iterable map object (an iterator) of the results.

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# **Question 10**:What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# Answer:Map Applies a given function to each item of an iterable like a list and returns a map object an iterator with the results.
#
# Python’s `reduce()` implements a mathematical technique commonly known as `folding` or `reduction`.
#  It is a process where you reduce a list of items to a single value
#
# filter : it is use to filter the unnecessary values from the list

# %% [markdown]
# **Question 11**:Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]
# answer : it is atteched to the file![question 11.jpg](data:image/jpeg;base64,...)
